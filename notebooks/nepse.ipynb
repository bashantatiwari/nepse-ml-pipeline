# %%
import pandas as pd
import numpy as np

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

merged_file = PROJECT_ROOT / "data" / "processed" / "nepse_merged_historical_data.csv"


df = pd.read_csv(merged_file)

df.head()
# Out:
#   published_date   open   high    low  close  per_change  traded_quantity  \
# 0     2010-09-16  117.0  122.0  116.0  120.0         NaN           5280.0
# 1     2010-09-19  120.0  120.0  116.0  118.0       -1.67           2648.0
# 2     2010-09-20  118.0  119.0  116.0  118.0        0.00           2346.0
# 3     2010-09-21  118.0  118.0  115.0  116.0       -1.69           7160.0
# 4     2010-09-23  116.0  120.0  117.0  120.0        3.45           8417.0
#
#    traded_amount  status symbol
# 0            0.0       0   ADBL
# 1            0.0       0   ADBL
# 2            0.0       0   ADBL
# 3            0.0       0   ADBL
# 4            0.0       0   ADBL

# %%
df.groupby("symbol").head(1).reset_index(drop=True).head(30)
# Out:
#    published_date   open   high    low  close  per_change  traded_quantity  \
# 0      2010-09-16  117.0  122.0  116.0  120.0         NaN           5280.0
# 1      2009-11-25  408.0  790.0  790.0  790.0         NaN             10.0
# 2      2018-12-25  102.0  102.0   98.0  101.0       -0.98            590.0
# 3      2017-07-02  421.0  420.0  405.0  410.0         NaN           3952.0
# 4      2010-06-13  226.0  233.0  223.0  226.0         NaN          13110.0
# 5      2015-12-29  371.0  381.0  368.0  372.0         NaN          13555.0
# 6      2015-10-28  388.0  426.0  395.0  419.0         NaN           5200.0
# 7      2011-06-26  386.0  400.0  393.0  400.0         NaN             44.0
# 8      2016-11-20  675.0  688.0  638.0  655.0         NaN          77691.0
# 9      2005-01-20  480.0  280.0  250.0  280.0         NaN           4230.0
# 10     2013-05-19  153.0  154.0  150.0  150.0         NaN          16083.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265702 entries, 0 to 265701
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   published_date   265702 non-null  object
#  1   open             265702 non-null  float64
#  2   high             265702 non-null  float64
#  3   low              265702 non-null  float64
#  4   close            265702 non-null  float64
#  5   per_change       265615 non-null  float64
#  6   traded_quantity  265702 non-null  float64
#  7   traded_amount    265702 non-null  float64
#  8   status           265702 non-null  int64
#  9   symbol           265702 non-null  object
# dtypes: float64(7), int64(1), object(2)
# memory usage: 20.3+ MB
